# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Привет, Данила :) Спасибо за все исправления и комментарии
#
# Критические ❌ комментарии
#
#
#
# + принять решение после проверки корректности заполнения пропусков синтетическими данными - оставить пропуски или поменять алгоритм
# + завершить фильтрацию редких значений в п. 2.4
#
# добавил подсказок и бонус
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Данила :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Ринат! Да, я не против перейти на ты.
#
# Посмотрел какими условными обозначениями ты будешь помечать свои комментарии. Всё понятно.
#
# Чтобы не засорять проект доп. комментариями от себя мне не хочется, по этому я оставил их, только там, где мне есть что добавить. Но все твои комментарии я не оставил без внимания, прочитал и внёс коррективы в код, оформление или вывод.
#
# По мере доработки проекта, у меня возникали гипотизы и возможные закономерности между данными. Но в связи с этим у меня позникает проблема: в погоне за более точной проработкой проекта и наглядным оформлением результата, я трачу на это слишком много времени. Этот проект однозначно можно сделать лучше, но первоначальная задача для меня, как ученика, это практика новых инструментов полученных за спринт.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принято

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться **определять рыночную стоимость** объектов недвижимости. Ваша задача — установить **параметры**. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ### План работы:
# 1. [Чтение и знакомство с исходными данными. Оценить примерный объём предобработки.](#section_1)
# 2. [Поиск и устронение: дубликатов, пропусков, аномалий и прочих ошибок.](#section_2)
# 3. [Дополнение таблицы информацией, необходимой для последующей работы.](#section_3)
# 4. [Поиск зависимостей между данными. Построение и проверка гипотиз. Графическое отображение результатов.](#section_4)
# 5. [Общий вывод по поставленной задаче. Перечень зависимых параметров и комментарии.](#section_5)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название, краткое вступление в работу и главная задача зафиксированы.
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, + будет легче  идти к главной цели проекта

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Добавил план работы. Не хватает тольео оформить его ввиде ссылок на соответстующий раздел документа. В Jupyter Notebook
# notebook есть такая возможность?

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Может пригодиться
#
# как реализовать интерактивный план проекта вручную (для собственных проектов), смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)

# %% [markdown]
# <a id='section_1'></a>
# # 1. Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
try:
    try: #чтение csv-файла, разделитель - табуляция: '\t'
        data = pd.read_csv('datasets/real_estate_data.csv', sep='\t') #домашняя версия
    except:
        data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t' ) #сетевая версия
    display(data.head())
except:
    print('Не удалось прочесть файл. Возможно, был указан не верный путь.')
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит делить блок загрузки библиотек и код загрузки датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %% [markdown]
# <div class="alert alert-dang
#             er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> в сетевой версии данные не загружены

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Для подгрузки данных стоит использовать конструкцию try-except, она поможет избежать потенциальных ошибок при загрузке данных, связанных, например, с некорректным указанием путей
#
# [Try - Except](https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Блок импорта библиотек добавил. Почему-то посчитал, что это принято только в C++.
#
# Касательно проблемы с подрузкой данных. Надеюсь я правильно тебя понял, что под сетевой версией ты подразумеваешь версию Jupyter Notebook, которая открывается прямо на сайте Яндекс Практикума. Да, в этом случае файл распологается по другому пути, и это вызвало ошибку. Это произошло потому, что я выполняю проект автономно на своём ноутбуке, и датафрей расположены в папке проекта.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Импорт библиотек стоит выносить на первые строки проекта, так коллегам будет удобнее настроить свои рабочие места под наши требования

# %%
data.hist(figsize=(15, 20))
plt.show()

# %% [markdown]
# <a id='section_2'></a>
# # 2. Предобработка данных.

# %% [markdown]
# Краткое описание надостатков данных и способов их исправления. Датафрэйм содержит всего **23699** записей и 22 колонки.
#
# Устранить **пропуски** с учётом типа данных:
# - [категориальные](#section_2_1): `is_apartment`, `locality_name`.
# - [количественные](#section_2_2): `ceiling_height`, `floors_total`, `living_area`, `kitchen_area`, `balcony`, `airports_nearest`, `cityCenters_nearest`, `parks_around3000`, `parks_nearest`, `ponds_around3000`, `ponds_nearest`, `days_exposition`.
#
# [Сменить **тип данных**](#section_2_3), на тот что им соответствует:
# - datetime <- `first_day_exposition`;
# - int <- `floors_total`, `balcony`, `parks_around3000`, `ponds_around3000`, `days_exposition`;
# - bool <- `is_apartment`.
#
# Для колонки `cityCenters_nearest` следует перезаписать **название** в едином формате _змеиный_регистр_.

# %%
data = data.rename(columns={'cityCenters_nearest' : 'city_centers_nearest'}) #переименовывание столбца

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Красота стиля важна для серъезных проектов, молодец

# %%
def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = 1, legend = False, fontsize = 16)
            .set_title('Доля пропусков в колонках датафрейма (значения в %)' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Я привык работать с абсолютными значениями, т.к они первоочерёдны и от них в последующем считаются относительные значения. Это без проблем могу сделать, если возникла такая необходимости. Но на случай, если каждую строчку проекто будут внимательно изучать, а не только вывод с готовыми ответами, то ДА -  стоит визуально отобразить данные. Надеюсь, позволишь оставить функцию, написанную тобой. Выглядить лаконично, но успел разобрать пока только половину.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />обязательно пользуйся и оптимизируй

# %% [markdown]
# <a id='section_2_1'></a>
# ## 2.1 Пропуски в категориальных данных

# %% [markdown]
# `locality_name` - **название населённого пункта**. Пропусков в этой колонке немного, всего 49 из 23699. Возможно пользовательно намеренно или по ошибке не заполнил соответствующее поле, т.к. оно не является обязательным для заполнения. Пропуски будут заменены на 'no_name'.
#
# Явные дубликаты - отсутствуют. Неявные дубликаты присутствуют. В первую очередь из-за использования буквы "ё" в названия населённых пунктов. От неё необходимо избавиться. Ничего личного.
# Помимо этого, некоторые населённые пункты указаны одновременно как города, так и сёла, посёлки, деревни. Ярким примером является Мурино, который получил статус города в 2019 году. До этого момента считался посёлком. В выборке пресутствуют объявления за несколько лет 2014-2019. По этой причине разные названия одного и того же насёленного пункта.
#
# Для упращения работы с данными, я привёл названия к сокращённому варианту. Визуально это воспринимается проще.

# %%
data['locality_name'] = data['locality_name'].fillna('no_name')
print("Кол-во пропусков в колонке 'locality_name':", data['locality_name'].isna().sum()) #Контроль

print("Кол-во явных дубликатов:", data.duplicated().sum()) #явные дубликаты отстутствую

items = [['ё', 'е'],
         ['садовое товарищество', 'СТ'],
         ['садоводческое некоммерческое товарищество', 'СНТ'],
         ['поселок городского типа', 'ПГТ'],
         ['коттеджный поселок', 'КП'],
         ['городской поселок', 'ГП'],
         ['поселок', 'п.'],
         ['деревня', 'дер.'],
         ['село', 'с.'],
         ['п. Мурино', 'Мурино'],
         ['п. Любань', 'Любань'],
         ['д. Кудрово', 'Кудрово'],
         ['с. Никольское', 'Никольское'],
         ['п. Рябово', 'ПГТ Рябово']]
for i in items:
    data['locality_name'] = data['locality_name'].replace(i[0], i[1], regex=True)

#print(data['locality_name'].value_counts()) #работа с неявными дубликатами
#print(sorted(data['locality_name'].unique()))
# Out:
# Кол-во пропусков в колонке 'locality_name': 0
# Кол-во явных дубликатов: 0

# %%
# check
data['locality_name'].nunique()
# Out:
# 327

# %% [markdown]
# `is_apartment` - **являетсли объект апартаметом** (да/нет). Пропуски составляют около 88%. Вероятней всего это связано с тем, что бОльшая чать недвижимости не являются апартаментами и пользователи просто игнарируют этот пункт. Заполню пустоты значением _False_.
# Для корректной замены, сразу исправлю несоответствия между данными и их типом, заменив его на _bool_.

# %%
data['is_apartment'].astype('bool')
data['is_apartment'] = data['is_apartment'].fillna(False)

print(data['is_apartment'].dtypes) #Контроль
print("Кол-во пропусков в колонке 'is_apartment':", data['is_apartment'].isna().sum()) #Контроль
# Out:
# bool
# Кол-во пропусков в колонке 'is_apartment': 0

# %% [markdown]
# <a id='section_2_2'></a>
# ## 2.2 Пропуски в количественных данных

# %% [markdown]
# `last_price` - **стоимость на момент снятия объявления** - пропуски отсутствуют, но необходимо избавиться от выбросов.

# %%
original_lengthe_df = data.shape[0]
data = data[data['last_price'] <= 40000000] #40 млн. руб.
print('Общая доля выбросов:', round((1 - data.shape[0]/original_lengthe_df)*100, 2),'%')
# Out:
# Общая доля выбросов: 0.77 %

# %% [markdown]
# `ceiling_height` - **высота потолков**. Для начала нужно избавиться от _артефактов_ типа: 25, 32, и т.п. По всей видимости в этих значениях ошиблись на один порядок. Для исправления достаточно поделить на 10, и значения будут преведены к одной ед. измерения - метрам.
#
# В числе современных квартир появляются объекты с общей высотой потолков свыше 4 метров. Это смещает среднее арифметическое значение в бОльшую сторону. Чтобы избежать этого влияния, будет использована _медиана_ для замены пропусков.
#
# Встречаются 2х этажные квартиры, или просто с высокими потолками. Для таких объектов высота обычно достигает 4 метров (исходя из списка актуальных объявлений квартир на том же самом Яндекс Недвижимость). Все значения свыше этого, будут считаться _аномалиями_ и будут удалены. Тоже самое касается объектов с высотой потолков ниже 2.5 метров.

# %%
print('Значения до:')
print('mean  ', data['ceiling_height'].mean())
print('median', data['ceiling_height'].median())
print('std   ', data['ceiling_height'].std())

data.loc[data['ceiling_height']>10, 'ceiling_height'] = data.loc[data['ceiling_height']>10, 'ceiling_height']/10
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median()) #замена пропусков на медиану
data = data[data['ceiling_height']<=4.0] #удаление объектов, с аномально высокими потолками
data = data[data['ceiling_height']>=2.4] #удаление объектов, с аномально низкими потолками

print('\n' + 'Значения после:')
print('Общая доля выбросов:', round((1 - data.shape[0]/original_lengthe_df)*100, 2),'%')
plt.boxplot(data['ceiling_height'])
data['ceiling_height'].describe()
# Out:
# Значения до:
# mean   2.7661041217765474
# median 2.65
# std    1.2636013285576617
#
# Значения после:
# Общая доля выбросов: 1.04 %
# count    23453.000000
# mean         2.691310
# std          0.199891
# min          2.400000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          4.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />При заполнении средним или медианой необходимо четко отслеживать изменение других статистик: стандартное отклонение, дисперсию и другие параметры выборки
#
# ... если рассмотреть районность высоты потолков, т.к. в современных районах Питера высота потолков будет ожидаема ниже, чем в исторических, мы увидим, что заполнение подобного объема пропусков медианой или средним значением «размажет» это отличительное свойство объектов недвижимости в центре Питера
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)

# %% [markdown]
# `rooms` - **количество комнат**. В выборке присутствуют еденичные экземпляры квартири с 6ю комнатами и более. При дальнейшем исследовании, они не будут учитываться, ввиду малого количества.

# %%
data = data[data['rooms']<=5] #удаление выбрасов
print('Общая доля выбросов:', round((1 - data.shape[0]/original_lengthe_df)*100, 2),'%')
# Out:
# Общая доля выбросов: 1.69 %

# %%
data[data['total_area'] < data['living_area']+data['kitchen_area']]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 184               7   2600000.0       30.20  2018-02-14T00:00:00      1
# 545               9   4700000.0       23.80  2018-12-28T00:00:00      1
# 551               8   3100000.0       31.59  2018-03-08T00:00:00      1
# 601              12   5600000.0       53.70  2017-04-18T00:00:00      2
# 696               1   3364930.0       34.69  2014-11-27T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 21824            20   2450000.0       44.00  2019-02-12T00:00:00      2
# 21868            12   2600000.0       34.30  2018-09-26T00:00:00      1
# 21915            14  11990000.0       91.40  2016-05-16T00:00:00      2
# 21956             0   5200000.0       46.00  2018-07-20T00:00:00      2
# 23202            13   4919880.0       67.92  2018-10-23T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# `living_area` - **жилая площадь квартиры**. Возможно применить два метода заполнения пропусков:
#
# **1)** Если в колонках `total_area` и `kitchen_area` присутствуют значения, то жилая площадь - разницей между площадью кухни и общей, за вычитом 18% относящиеся к нежелой площади (коридоры, ванные, кладовые, и т.п.).
#
# **2)** В противном случае замена будет осуществляться на медиану, в зависимости от кол-ва комнат. Благо в столбце `rooms` - отсутствуют пропуски, и на их основе можно сделать справочную таблицу, со сред. площадями для каждой N-комнатной квартиры. Значение для удоста округлено до 2х знаков после запятой.
#
# Похожую процедуру замены параллельно выполню для колонки `kitchen_area` - **площадь кухни**. Следует сделать уточнение для квартир типа: студия. У них отстутсвует разделение между жилой площадью и кухней. По этой причине, площадь кухни в студиях будет принята за _ноль_.
#
# В выборке встречаются объекты, общая площадь которых многократно превышает жилую площадь. Это свойственно для _частных домов_ или _таунхаусов_ со большим количеством хоз. помещений (котельная, электрощитовая, гараж и т.п.). Для исследования - они лишние, т.к. в выборке должны содержаться квартиры, о чём говориться в описании иходных данных. Помимо них будут отброшены малочисленные объекты, особо выделяющиеся из общей массы - _выбросы_.

# %%
#display(data.pivot_table(index='rooms', values=['living_area', 'kitchen_area'], aggfunc=['mean', 'median', 'std']))

# 1ый способ устранения пропусков
data.loc[data['rooms']==0, 'kitchen_area'] = data['kitchen_area'].fillna(0) #площадь кухни в квартира-студиях
data.loc[(data['living_area'].isna()) & (~data['kitchen_area'].isna()), 'living_area'] = (
                                                                                0.82*data['total_area'] - data['kitchen_area'])
data.loc[(data['kitchen_area'].isna()) & (~data['living_area'].isna()), 'kitchen_area'] = (
                                                                                0.82*data['total_area'] - data['living_area'])
data.loc[data['kitchen_area']<5, 'kitchen_area'] = 0


# 2ой способ устронения пропусков
rooms_type = sorted(data['rooms'].unique()) #список N-комнатных квартир
living_area_mean = list(round(data.groupby('rooms')['living_area'].median(), 2)) #список средних площадей
kitchen_area_mean = list(round(data.groupby('rooms')['kitchen_area'].median(), 2)) #список средних площадей
info = [] #объявление и заполнение массива, который будет содержать данные для создания справочного дата фрейма
for i in range(len(rooms_type)):
    info.append([rooms_type[i], living_area_mean[i], kitchen_area_mean[i]])
table_area = pd.DataFrame(data=info, columns=['rooms', 'living_area_mean', 'kitchen_area_mean']) #справочная таблица

for room in rooms_type: #цикл замены пропускав
    data.loc[data['rooms']==room,'living_area'] = (data.loc[data['rooms']==room, 'living_area']
                                                .fillna(float(table_area.loc[table_area['rooms']==room, 'living_area_mean'])))
    data.loc[data['rooms']==room,'kitchen_area'] = (data.loc[data['rooms']==room, 'kitchen_area']
                                                .fillna(float(table_area.loc[table_area['rooms']==room, 'kitchen_area_mean'])))

# вычетание нежилой площади из завышенной площади кухни и жилой
anomaly_area = data.loc[data['total_area'] < data['living_area']+data['kitchen_area'],
                        ['total_area', 'living_area', 'kitchen_area']]
anomaly_area['living_area'] -= anomaly_area['total_area']*0.24
anomaly_area['kitchen_area'] -= anomaly_area['total_area']*0.12
data.loc[data['total_area'] < data['living_area']+data['kitchen_area'], 'living_area'] = anomaly_area['living_area']
data.loc[data['total_area'] < data['living_area']+data['kitchen_area'], 'kitchen_area'] = anomaly_area['kitchen_area']
    
# удаление выбросов
data = data[data['total_area']<=200]
data = data[(10<=data['living_area']) & (data['living_area']<=170)]
data = data[((5<=data['kitchen_area']) & (data['kitchen_area']<=40)) | (data['kitchen_area']==0)]
data = data[data['total_area'] > data['living_area']+data['kitchen_area']]
print('Общая доля выбросов:', round((1 - data.shape[0]/original_lengthe_df)*100, 2),'%')

#display(data.pivot_table(index='rooms', values=['living_area', 'kitchen_area'], aggfunc=['mean', 'median', 'std']))
print("Кол-во пропусков в колонке 'living_area':", data['living_area'].isna().sum()) #Контроль
print("Кол-во пропусков в колонке 'kitchen_area':", data['kitchen_area'].isna().sum())
# Out:
# Общая доля выбросов: 2.81 %
# Кол-во пропусков в колонке 'living_area': 0
# Кол-во пропусков в колонке 'kitchen_area': 0

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />После заполнения синтетическими данными столбцов, стоит провести проверку на корректность значений всех наших площадей, т.к. есть (коридоры, сан.узлы, балконы)
#
#         total_area*0.9 <= (living_area + kitchen_area)
#
# если алгоритм приводит к появлению аномалий, стоит подумать над его содержимым

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Изначально, я предполагал, что потребуется добавить коэффициент для корректировки. Допустим, на нежелые площади (коридоры, сан.узлы, балконы и т.п.) отвести 10%, то следовательно площадь кухни и жилая составит 90%. Добавив это в формулу для расчётов ввиде коэф 0.9, появляются отрицательные значения.
#
# Это может быть следствием того, что некоторые пользователи не выделяют коридоры, сан.узлы, балконы в отдельный тип площади и сумируют с жилой, либо площадь кухни уже где-то учтена, например она совмещена с гостинной (недавно узнал, что для Турции это обыденность).
#
# Добавленный коэф. я считаю, стоит оставить, т.к. среднее отклонение меньше, чем без использовании коэф. А отрицательные значения площади кухни заменить на ноль.

# %% [markdown]
# ### check area

# %%
# check
data[data['total_area']*0.9 <= (data['living_area'] + data['kitchen_area'])][['total_area','living_area','kitchen_area']]
# Out:
#        total_area  living_area  kitchen_area
# 41           74.0         59.0         12.00
# 164          40.3         30.5          8.83
# 171          49.0         38.0         10.00
# 195          60.0         45.0          9.50
# 319          59.7         47.4          6.40
# ...           ...          ...           ...
# 23216       114.0         90.2         16.00
# 23328        54.0         40.0         10.00
# 23500        29.0         17.7          9.00
# 23521        65.0         44.0         15.30
# 23601        43.4         30.5          8.83
#
# [478 rows x 3 columns]

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Кол-во аномалий после заполнения синтет. данными пропусков выросло с 475 изначальных записей до 1854, стоит подумать над алгоритмом заполнения - или изменить алгоритм, или оставить пропуски
#
# __Самое важное — приобрести навык__ — любая замена пропусков очень трудоемка по ресурсам, т.к. приходится искать оптимальный вариант и если можно работать, имея пропуски в данных — лучше отказаться от заполнения
#
# но есть другие случаи, когда пропуски заполнять обязательно нужно, на проекте по стат. анализу — внимательно посмотри на пропуски в данных в объединенной таблице (кроме даты оттока клиентов)
#
# в итоге каждый раз мы вынуждены будем принимать решение — заполнять пропуски и как заполнять, или оставлять

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента (v2)</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Общую площадь квартиры можно поделить на 3 группы: жилая (спальни, гостинные), кухня, и нежелые площади (коридоры, ванные, и т.п.) Но мне не ясно на основе чего определяется доля нежелой площади, относительно общей. Каков процент 15, 16 ,17? Почему не 10% Как определяется? На глаз, по опыту? Я ориентировался на уменьшение кол-ва аномальных значений.
#
# Я постарался уменьшить число аномалий, но чувствую что больше и больше вхожу в ступор, и попросту не знаю что делать.

# %% [markdown]
# `balcony` - **количество балконов**. Наличие пропусков вероятней всего говорит об отсутствие балкона. По этой замена будет производится на 0.

# %%
data['balcony'] = data['balcony'].fillna(0)
print("Кол-во пропусков в колонке 'balcony':", data['balcony'].isna().sum()) #Контроль
# Out:
# Кол-во пропусков в колонке 'balcony': 0

# %% [markdown]
# `parks_around3000` — **число парков в радиусе 3 км**. Логично предположить, если в `parks_nearest` указано расстояние до ближайшего парка, и оно меньше 3000 метров, то как минимум одни парк поблизости присутствуети и пропуск можно заменить на 1.
# Но таковых объектов не оказалось. Проверка показала, что если указано растояние до парка, то указано и их количество.
# В таком случае замена будет производиться на 0, т.к. не получается найти подтверждения наличия парков поблизости.
#
# `ponds_around3000` — **число водоёмов в радиусе 3 км**. Процедура замены - аналогична.
#
# `parks_nearest` и `ponds_nearest` — **расстояние до ближайшего парка** и **водоёма**, соответственно. Замена на любое, ненулевое значение не имеет смысла, т.к. это исказит исходные данные.

# %%
# Проверка вышеописанного предположения
#display(data.loc[(~data['parks_nearest'].isna()) & (data['parks_around3000'].isna())])
#display(data.loc[(~data['ponds_nearest'].isna()) & (data['ponds_around3000'].isna())])

data.loc[data['parks_nearest'].isna(),'parks_around3000'] = data.loc[data['parks_nearest'].isna(),'parks_around3000'].fillna(0)
data['parks_nearest'] = data['parks_nearest'].fillna(0)

data.loc[data['ponds_nearest'].isna(),'ponds_around3000'] = data.loc[data['ponds_nearest'].isna(),'ponds_around3000'].fillna(0)
data['ponds_nearest'] = data['ponds_nearest'].fillna(0)

print("Кол-во пропусков в колонке 'parks_around3000':", data['parks_around3000'].isna().sum()) #Контроль
print("Кол-во пропусков в колонке 'parks_nearest':", data['parks_nearest'].isna().sum()) 
print("Кол-во пропусков в колонке 'ponds_around3000':", data['ponds_around3000'].isna().sum())
print("Кол-во пропусков в колонке 'ponds_nearest':", data['ponds_nearest'].isna().sum())
# Out:
# Кол-во пропусков в колонке 'parks_around3000': 0
# Кол-во пропусков в колонке 'parks_nearest': 0
# Кол-во пропусков в колонке 'ponds_around3000': 0
# Кол-во пропусков в колонке 'ponds_nearest': 0

# %% [markdown]
# `airports_nearest` — **расстояние до ближайшего аэропорта**. Вероятней всего данный в этой графе отсутствуют, потому как объект недвижимости находится в населённом пункте, в котором нет аэропорта, либо растояние до него слишком велико, чтобы это имело значение. В этой связи пропуски будут заменены на 0.

# %%
#display(data[data['airports_nearest']==0])
data['airports_nearest'] = data['airports_nearest'].fillna(0)
print("Кол-во пропусков в колонке 'airports_nearest':", data['airports_nearest'].isna().sum()) #Контроль
# Out:
# Кол-во пропусков в колонке 'airports_nearest': 0

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоило проверить наличие нулевых значений в записях перед заполнением
#
#         data['airports_nearest'] = data['airports_nearest'].fillna(0)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Для квартир, у которых не указано расстояние до аэропорта, я отвёл значение 0 метров, т.к. в действительности не может быть такого, чтобы квартира находилась на территории аэропорта. В эту же группу попала квартира, у которой изначально было указано расстояние 0 метров. В дальнейшем исследовании эти объекты будут игнорироваться с помощью указания диапазона значений.

# %% [markdown]
# `floors_total` — **общее кол-во этажей**. Замена будет недостоверна и исказит исходные данные. Но благо таких квартир не много (86 шт.), от них можно избавиться.

# %%
data = data[~data['floors_total'].isna()]
data = data[data['floors_total'] <= 37]
print('Общая доля выбросов:', round((1 - data.shape[0]/original_lengthe_df)*100, 2),'%')
# Out:
# Общая доля выбросов: 3.18 %

# %% [markdown]
# `days_exposition` - **количество дней размещения объявления**. Это значение вычисляется разничей между первым и последним днём публикации обявления. Пропуски можно устранить если в распоряжении были даты завершения публикации, помимо `first_day_exposition`. По этой причине, избавлюсь тольк от аномалий, удалив квартиры со сроком продажи более 800 дней. В этом  случае, будет оброшено небольшой процент данных.

# %%
#data['days_exposition'].hist(bins=100)
data = data[(data['days_exposition'] < 800) | (data['days_exposition'].isna())]
print('Общая доля выбросов:', round((1 - data.shape[0]/original_lengthe_df)*100, 2),'%')
# Out:
# Общая доля выбросов: 5.53 %

# %% [markdown]
# `city_centers_nearest` - **расстояние до центра города** (замена исказит исходные данные).

# %%
pass_value_barh(data) #Итоговый контроль

# %% [markdown]
# <a id='section_2_3'></a>
# ## 2.3 Изменение типов данных

# %% [markdown]
# Сменить **тип**, исходя из содержания данных, на более соответствующий:
# - `first_day_exposition` - содержит дату публикации обявления, чему соответствует тип `datetime`. После смены типа данных в колонке будет отображаться только дата, т.к. время везде имеет одинаковое и нулевое значение;
# - `last_price`, `floors_total`, `balcony`, `parks_around3000`, `ponds_around3000` - эти колонки содержат только целочисленные значения. Может быть только целое количество балконов. Только целое кол-во парков и т.д. Это соответствует типу `int`;

# %%
data['first_day_exposition'] =  pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

for column in ['last_price', 'floors_total', 'balcony', 'parks_around3000', 'ponds_around3000']:
    data[column] = data[column].astype('int')

data.info() #Контроль типов данных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22388 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22388 non-null  int64
#  1   last_price            22388 non-null  int32
#  2   total_area            22388 non-null  float64
#  3   first_day_exposition  22388 non-null  datetime64[ns]
#  4   rooms                 22388 non-null  int64
#  5   ceiling_height        22388 non-null  float64
#  6   floors_total          22388 non-null  int32
#  7   living_area           22388 non-null  float64
#  8   floor                 22388 non-null  int64
#  9   is_apartment          22388 non-null  bool
#  10  studio                22388 non-null  bool
#  11  open_plan             22388 non-null  bool
#  12  kitchen_area          22388 non-null  float64
#  13  balcony               22388 non-null  int32
#  14  locality_name         22388 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />цикл for скучает
#
#         data['balcony'] = data['balcony'].astype('int')
#         data['last_price'] = data['last_price'].astype('int')
#         data['parks_around3000'] = data['parks_around3000'].astype('int')
#         data['ponds_around3000'] = data['ponds_around3000'].astype('int')

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# стоит сменить тип данных в
#
#
#          6   floors_total          23291 non-null  float64
#
# пропуски можно удалить, кол-во их минимально

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> "цикл for скучает" - блин :D точно! Этот блок заполнялся постепенно, в порядке работы с определённым столбцом. Таким образом и вырасла эта последовательность однообразных строк.
#
# В колонке floors_total - пропуски удалены, установлен предел от выбросов, добавлен текстовый комментарий.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_98acf_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_98acf_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_98acf_row0_col0" class="data row0 col0" >22,388.00</td>
#                         <td id="T_98acf_row0_col1" class="data row0 col1" >22,388.00</td>
# ...

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости в колонках:
#
#         'total_area', 'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floors_total'
#
# стоит учесть наличие пропусков при фильтрации данных

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости в колонках:
#
#         'days_exposition', 'living_area',  'kitchen_area'
#
# стоит учесть наличие пропусков при фильтрации данных

# %%
# check
data.hist(column = 'kitchen_area', bins = 50, figsize = (15,3), range = (0.1, 5));

# %%
data.hist(column = 'days_exposition', bins = 100, figsize = (15,3), range = (0, 800));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выполнения пункта 2.4. существует два подхода
#
# Можно механически бороться с выбросами, ...
#
# основная проблема такого подхода — не учитывается неоднородность нашей выборки: у нас здесь и малые поселки, и вторая столица страны, и исторический фонд и массовая застройка, и однушки и довольно большое кол-во многокомнатных квартир, или наоборот одна две квартиры с количеством комнат больше 7-ми ...
#
#
#
# если бы у нас в таблице были бы только однокомнатные квартиры из определенного района массовой застройки, тогда да, мы бы боролись с выбросами традиционными способами, при нашем многообразии населенных пунктов, многокомнатности такие подходы не работают... т.е. они работают, но это усложнит наш проект — придется разбить и объединить записи нашей таблицы по нескольким параметрам (кол-во комнат, район, и т.д.), а затем только выполнять все остальные пункты на каждой отдельной выборке
#
# Остается другой подход — убираем редкие значения и следим за количеством потерь...
#
# Для выборки из 23-х тысяч значений, 4 записи со стоимостью квадратного метра выше 10 млн. руб., довольно редкое явление
#
# Хороший пример, высота потолков, которую мы отрезаем по нижней и верхней планке, это скорее аномальные записи, посмотрим на другой аспект — на редкости: кол-во комнат
#
# __т.е. мы не говорим о том, что квартир с кол-ом комнат выше 7 не бывает, мы говорим, что для нашего исследования это редкие выбивающиеся из общей картины уникальные объекты, по которым необходимо проводить отдельную работу ...__
#
# подобным образом рассматриваем и остальные параметры
#
# наши помощники
#
# 1. гистограммы, с хорошим масштабом
# 2. метод describe() или облегченная версия, пример выше
# 3. метод value_counts()
#
# плюс жизненный опыт

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> В проекте ты часто ссылаешься на пункт 2.4. Правильно ли я понимаю, что на самом деле ты подразумевал пункт: "2.2 Пропуски в количественных данных"?
#
# Соглашсь, что скурпулёзный механический подход - сложен, Но по моему мнению, он подходящий, т.к. по своей сути приметивен и позволяет простыми операциями достич более-менее внятного результата. Тем более это позволило мне выстроить технику работы с данными, и познакомиться с различными вариантами их ошибок. Следил за долей отброшенных выбросов.
#
# Делая этот проект во второй раз, я бы заменил однотипными операции вызовом собственной функции, написанной один раз. Это для примера.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />п. 2.4.
#
# ![image.png](attachment:image.png)

# %%
# check

data.rooms.value_counts().to_frame()
# Out:
#    rooms
# 1   7792
# 2   7645
# 3   5489
# 4   1043
# 5    234
# 0    185

# %%
# check
data.total_area.hist(bins = 150, figsize = (15,3));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры более 250-ти квадратных метров можно считать редкостями
#
# особенно это заметно на втором графике, где мы подробно рассматриваем промежуток от 180 кв. метров до 500

# %%
# check
data.total_area.hist(bins = 150, figsize = (15,3), range = (180,500));

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось завершить выполнение пункта 2.4 из брифа проекта
#
# 2.4.	Найдите и устраните редкие и выбивающиеся значения.
#
# __Критичный уровень потерь записей на этапе предобработки составляет 10%, оптимальный 5%__

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.01, .5, .90, .9976])  
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_58761_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_58761_level0_row0" class="row_heading level0 row0" >0.01</th>
#                         <td id="T_58761_row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_58761_row0_col1" class="data row0 col1" >25.69</td>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Квантили что это такое
#
# https://fin-accounting.ru/cfa/l1/quantitative/cfa-quartiles-quintiles-deciles-percentiles?ysclid=l7gy2kky4i156375632
#
# они помогают увидеть редкости и аномалии в данных

# %% [markdown]
# <a id='section_3'></a>
# # 3. Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# Добавьте в таблицу новые столбцы со следующими параметрами:
# - цена одного квадратного метра;
# - день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# - месяц публикации объявления;
# - год публикации объявления;
# - тип этажа квартиры (значения — «‎первый», «последний», «другой»);
# - расстояние до центра города в километрах (переведите из м в км и округлите до целых значений).
#
# После добавления новых столбцов, выполнить перегруппировку столбцов: расположив их в порядке убывания значимости и группируя по смыслу.

# %%
data['price_meter'] = data['last_price']/data['total_area'] #стоимость кв. метра. Название сокращено для удобства.
data['price_meter'] = data['price_meter'].astype('int') #округление до рублей, копейки - лишние.

data['day_week_exposition'] = data['first_day_exposition'].dt.weekday
data['month_exposition'] = data['first_day_exposition'].dt.month
data['year_exposition'] = data['first_day_exposition'].dt.year

data.loc[data['floor']==1,'floor_type'] = 'первый'
data.loc[data['floor']==data['floors_total'],'floor_type'] = 'последний'
data.loc[(data['floor']!=1) & (data['floor']!=data['floors_total']),'floor_type'] = 'другой'

data['city_centers_nearest_km'] = (data['city_centers_nearest']/1000).round()

data = data.reindex(columns=['locality_name', 'rooms', 'last_price', 'price_meter', 'total_area', 'living_area', 'kitchen_area',
                             'balcony', 'ceiling_height', 'floors_total', 'floor', 'floor_type', 'is_apartment', 'studio',
                             'open_plan', 'total_images', 'airports_nearest', 'city_centers_nearest', 'city_centers_nearest_km',
                             'parks_around3000', 'parks_nearest', 'ponds_around3000', 'ponds_nearest',
                             'days_exposition', 'first_day_exposition',
                             'day_week_exposition', 'month_exposition', 'year_exposition'])
display(data.head()) #Контроль
# Out:
#      locality_name  rooms  last_price  price_meter  total_area  living_area  \
# 0  Санкт-Петербург      3    13000000       120370       108.0         51.0
# 1        п. Шушары      1     3350000        82920        40.4         18.6
# 2  Санкт-Петербург      2     5196000        92785        56.0         34.3
# 5       ГП Янино-1      1     2890000        95065        30.4         14.4
# 6     п. Парголово      1     3700000        99195        37.3         10.6
#
#    kitchen_area  balcony  ceiling_height  floors_total  ...  \
# 0          25.0        0            2.70            16  ...
# 1          11.0        2            2.65            11  ...
# 2           8.3        0            2.65             5  ...
# 5           9.1        0            2.65            12  ...
# 6          14.4        1            2.65            26  ...
#
#    city_centers_nearest_km parks_around3000  parks_nearest  ponds_around3000  \
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />алгоритм категоризации этажей хороший, стоит учесть крайние условия: нулевые и отрицательные значения
#
# оптимальнее использовать функцию, чтобы три раза не обращаться к датасету

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> данные добавлены корректно, молодец

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Я написал самый приметивный и понятный алгоритм категоризации этажей. Т.к. он используется всего один раз, я не стал объявлять, описывать и вызывать функцию. В лучшем случае код занял тот же объём, но смотрелся сложнее. Хотя это технически верное решение. Думаю, что с бОльшим объёмом данных функция была бы эффективней.
#
# Нулевые и отрицательные значения этажей, я проверил. Т.к. они отсутствовали я не стал писать дополнительны код. Он был бы бесполезен.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />в следующем месяце мы можем работать с базой недвижимости Москвы или Торонто, в которых могут встретиться полуподвальные или подвальные помещения ...
#
# универсальная функция ценится тем, что её программируют один раз, а используют множество раз

# %% [markdown]
# <a id='section_4'></a>
# # 4. Проведите исследовательский анализ данных

# %% [markdown]
# ## 4.1. Изучение предобработанных данных

# %% [markdown]
# Постройте отдельные гистограммы для каждого из этих параметров. Опишите все ваши наблюдения.
# - общая площадь;
# - жилая площадь;
# - площадь кухни;
# - цена объекта;
# - количество комнат;
# - высота потолков;
# - этаж квартиры;
# - тип этажа квартиры («первый», «последний», «другой»);
# - общее количество этажей в доме;
# - расстояние до центра города в метрах;
# - расстояние до ближайшего аэропорта;
# - расстояние до ближайшего парка;
# - день недели и месяц публикации объявления.

# %% [markdown]
# **Площадь(общая, жилая, и кухни).** Результат напоминает распределение _Пуасона_, с некоторыми особенностями, а именно: в диапазоне околонувых значений площади - крайней мало объектов. После, идёт очень резкий рост до самой популярной площади, по преодолению которого следует плавный спад.
#
# На всех гистограммах просматривается неравномерность распределения: превышение, занижение некоторых значенией. Легко заменить пиковые значения площадей кухни и жилого пространства. Это связано с огромных количеством _типовых строений_: хрущевка, сталинка, брежневка. Размеры квартир и внутренних помещений были _стандартизированы_. Такие дома строились в огромном количестве по всей стране, в том числе на территории Ленинградской области. Помимо этого на внещний вид распределения повлияли _пропуски в исходных данных_. Такой вывод я могу сделать проведя аналогию с колонкой "Общая площадь", пропуски в которой - отсутствуют.

# %%
data['total_area'].plot(kind='hist', bins=60, figsize=(15,5), grid=True, title='Общая площадь (значения в кв.м.)')
plt.ylabel('Количество квартир, шт.')
plt.xlabel('Площадь, кв.м.')
plt.show()

data['living_area'].plot(kind='hist', bins=56, figsize=(15,5), grid=True, title='Жилая площадь (значения в м.кв.)')
plt.ylabel('Количество квартир, шт.')
plt.xlabel('Площадь, кв.м.')
plt.show()

data['kitchen_area'].plot(kind='hist', bins=80, figsize=(15,5), grid=True, title='Площадь кухни (значения в м.кв.)')
plt.ylabel('Количество квартир, шт.')
plt.xlabel('Площадь, кв.м.')
plt.show()

# %% [markdown]
# Гистограмма **стоимостей объектов**, напоминает нормельное распределение с длинным "хвостом" справа. Это связано с тем, что в Санкт-Петербурге встречаются исключительные объекты с особой исторической ценностью. Ярко выраженны максимум и симметричность.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Хорошие графики, можно добавить подписи осей
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://pyprog.pro/mpl/mpl_axis_signatures.html) и [там](https://pyprog.pro/mpl/mpl_title.html), и [тут](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Спасибо за ссылки. Полезный материал. Я добавил больше пояснений к графикам, но только таким образом. По непонятной мне причине, я не могу добавить подпись для оси Х. Строчка:
#
#         plt.xlabel('Площадь, кв.м.')
#
# Вызывает ошибку:
#
#         TypeError: 'str' object is not callable
#
# Я посчитал, что ему может мещать атрибут title, но убрав его результата это не принесло. Хотя функция plt.xlabel() работает без проблем.
#
# На следующем графике я пробовал, но не смог поменять размерность значений по оси Х. Она указана в нижнем правом углу "le7" - 7 порядков после запятой. Куда лучше бы смотрелась 6 порядков - это в акурат миллион, и значения вдоль оси Х, были бы целыми.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />"le7" - 7
#
#         это 10 000 000 руб.
#
# plt.xlabel('Площадь, кв.м.')
#
#         добавил, ошибки нету

# %%
data['last_price'].plot(kind='hist', bins=80, figsize=(15,5), grid=True,
                        title='Соотношение количиства объектов, в зависимости от общей стоимости')
plt.ylabel('Количество квартир, шт.')
plt.show()

# %% [markdown]
# Гистограмма **кол-ва комнат** демонстрирует большой объём предложений о продаже 1-а, 2-х, 3-х комнатных квартир. Значительно меньше этот показатель у 4х и 5ти комнатных квартир. И минимальное кол-во 6ти комнатных квартир и студий.

# %%
data['rooms'].plot(kind='hist', bins=11, figsize=(15,5), range=(-0.25, 5.25), grid=True,
                   title='Численность N-комнатных квартир', ylabel='Количество, шт.')
plt.ylabel('Количество квартир, шт.')
plt.show()

# %% [markdown]
# Среди **высот потолков** особо выделяются три значения:
# - 2.50м - минимальнодопустимая высота для жилых помещений согласно СНиП (Строительные нормы и правила),
# - 2.65м - "современный" стандарт новых квартир,
# - 3.00м - новостройки повышенного класса комфорта.

# %%
data['ceiling_height'].plot(kind='hist', bins=16, figsize=(15,5), grid=True,
                           title='Зависимость кол-ва квартир от высоты потолков (значения указаны в метрах)')
plt.ylabel('Количество квартир, шт.')
plt.show()

# %% [markdown]
# **Этажи.** Гистограмма расположения квартир по этажам имеет вид _распределения Пуасона_, с пиковым значение: 2ой этаж. Количество "первых" и "последний" этажей - примерно одинаково, и каждый ориентировочно составляют 13% от общего числа квартир. Среди _этажности_ домов особо распространены: 5-ти и 9-ти "этажки" массовой застройки советского периода. В меньшей степени: 11, 13, 17, 26.

# %% [markdown]
# <div class="alert alert-da
#             nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы, сейчас может показаться, что в
#
#         Среди этажности домов особо распространены: 5 и 10. В меньшей степени: 11, 13, 17, 26.

# %%
data['floor'].plot(kind='hist', bins=32, range=(1, 33), figsize=(15,5), grid=True, title='Этаж квартиры')
plt.ylabel('Количество квартир, шт.')
plt.show()

data.groupby('floor_type')['floor_type'].count().plot(kind='pie', figsize=(7,7), title='Тип этажа')
plt.ylabel('Количество квартир, шт.')
plt.show()

data['floors_total'].plot(kind='hist', bins=36, range=(1, 37), figsize=(15,5), grid=True, title='Этажность дома')
plt.ylabel('Количество квартир, шт.')
plt.show()

# %% [markdown]
# **Инфраструктура.** Рядом расположенные объекты: центр города, аэропорты, парки.
#
# Под "цетром города" в большинстве слуаев подразумевается центр обласного города - Санкт-Петербрга. На гистограмме отображающая _расстояние до центра города_ просматривается четыре фиругы нормального распределения, с небольшим перекрытием:
# 1) 1 - 10000 метров. Первый диапазон заполнен квартирами, расположенные в самом городе. Городская территория имеет около круглую границу, радиус которой около 13-15км. За пределами этой границы уже располагается территория области или другой населённый пункт. и в среднем расстояние до центра составляет 5 км.
#
# 2) 5 - 20км. Второй диапазон занимают квартиры городов-спутников СПБ. Около границы КАДа (кольцевая автодорога) - огромное количество предложений о продаже квартир. Большинство из них распологается в 12-16км. от центра Петербурга. Очевидно как город "растёт" в ширь.
#
# 3) 30±5 км. Ряд крупных городов: Кронштадт, Красное Село, Сестрорецк, и др.
#
# 4) 40±3 км. Гатчина, Ульяновка, Шлисельбург и др.
#
# 5) 50±5 км. Рощино, Тосно, и большое количество малонаселённых поселений.
#
# *Диапазон значений, отображаемый на гистограмме, начинается с 1 по причине того, что у ряда квартир пропуски в данных заменены на ноль.

# %%
data['city_centers_nearest_km'].plot(kind='hist', bins=59, range=(1, 60), figsize=(15,5), grid=True,
                                     title='Расстояние до центра города (в километрах)')
plt.ylabel('Количество квартир, шт.')
plt.show()

# %% [markdown]
# В контексте **расстояния до аэропорта**, квартиры распределены достаточно хаотично. Большая часть значений находятся в диапазоне от 10 до 60 км. За редким исключением 6-9 км. Квартиры ближе 5 км. от аэропорта - не встречается.
#
# Если рядом с квартирой **поблизости находится парк**, то расстояние до него в среднем около 500 метров, но не больше 1 километра.

# %%
data['airports_nearest'].plot(kind='hist', bins=60, range=(1, 60000), figsize=(15,5), grid=True,
                              title='Расстояние до аэропорта (в метрах)')
plt.ylabel('Количество квартир, шт.')
plt.show()

data['parks_nearest'].plot(kind='hist', bins=60, range=(1, 3000), figsize=(15,5), grid=True,
                           title='Расстояние до парка (в метрах)')
plt.ylabel('Количество квартир, шт.')
plt.show()

# %% [markdown]
# **Дата публикаций.**
#
# Наибольшая интенсивность публикаций приходится на рабочие _дни недели_, между которыми есть небольшие отличия: Вторник, четверг - максимум. Среда, пятница - средняя интенсивность. Понедельний - манимальная. _Выходные_ я намеренно выделяю из всей недели, т.к. в эти дни публикуют в 2 раза меньше. Так же просматривается _эффект инерции_: в понедельник не все успевают активизироваться с началом рабочей недели. Аналогичная ситуация в субботу, некоторые пытаются закончить дела уходящей недели.
#
# Лидеры среди _месяцев_: февраль, март, апрель. Далее май - самый непродуктивный месяц. Вероятней всего это связано с началом периода отпусков и дачного сезона. За этим месяцем следует равномерный рост вплоть до ноября, в который кол-во публикация достигают максимальных значений. Декабрь и январь - период "застоя", связанный с предпразничной подготовкой до НГ, и почти пол месяцы выходных после.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Интересно, почему февраль (28 дней) опережает все месяцы — ?__

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> При одинаковой интенсивности между месяцами, февраль бы проигрывал, т.к. на меньшее количество дней приходилось бы меньшее количество публикаций. Я считаю, что количество дней тут не причём. А причина кроется в квартирах публикация которых "отложенна" с января. Предполагаю, что сама потребность продажи квартиры - равномерна. А обнародовании этой потребности, т.е. размещение объявления парой откладывается до момента "когда время будет посвободней", и это точно не период массовых  новогодних каникул.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Все проще, в один из февралей какого-то года произошел выброс объявлений

# %%
data['day_week_exposition'].plot(kind='hist', bins=13, range=(-0.25, 6.25), figsize=(15,5), grid=True,
                                 title='День недели публикации объявления')
plt.ylabel('Количество публикаций, шт.')
plt.show()

data['month_exposition'].plot(kind='hist', bins=23, range=(0.75, 12.25), figsize=(15,5), grid=True,
                              title='Месяц публикации объявления')
plt.ylabel('Количество публикаций, шт.')
plt.show()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %% [markdown]
# ##
# ## 4.2. Исследовательские задачи

# %% [markdown]
# ### Задание №1
# Изучите, как быстро продавались квартиры (столбец `days_exposition`). Этот параметр показывает, сколько дней «висело» каждое объявление.
# - Постройте гистограмму.
# - Посчитайте среднее и медиану.
# - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"

# %% [markdown]
# В среднем, квартиры продаётся за полгода, но т.к. диапазон значений сильно растянут и в редких случаях период продажи до 4х лет, нельзя полагаться на _среднее арифметическое_. Более соответствует действительности _медиана_: 95 дней. Продажи длящиеся больше этого значения можно считать "вялотекущими". А по прошествию рубежа в 180 дней - необычно долгими.
#
# Если рассматривать весь диапазон значений, то можно заменить экспоненциальное распределение. Но большая часть продаж содержиться в промежутке до 100 дней. Он отображен на втором графике. Первые 3 дня практически никто не продаёт квартиру - это минимальное время, которое необходимо для принятия решения. Особо выделяются 45-ой и 60-ый дни - с чем это связано сказать трудно, но это точно не случайность а конкретное действий в жесткой зависимости от времени. У меня есть предположение: по прошествию 45 суток после первичной публикации (или 60 суток после повторной публикации), квартира автоматически снимается с продаж и считается условно проданной. Если пользователь не проявит активность и не продлит публикацию объявления.

# %%
clear_days_data = data[~data['days_exposition'].isna()]

display(clear_days_data['days_exposition'].describe())
plt.boxplot(clear_days_data['days_exposition'])
plt.title('Диаграмма размаха срока продажи квартир')
plt.show()

clear_days_data['days_exposition'].plot(kind='hist', bins=166, figsize=(15,5), grid=True, title='Срок продажи квартиры',
                                        range=(clear_days_data['days_exposition'].quantile(0.25),
                                               clear_days_data['days_exposition'].quantile(0.75)))
plt.ylabel('Количество публикаций, шт.')
plt.show()

clear_days_data.pivot_table(index='year_exposition', values='days_exposition', aggfunc=['count', 'median', 'mean', 'std'])
# Out:
# count    19370.000000
# mean       154.776871
# std        164.033333
# min          1.000000
# 25%         44.000000
# 50%         90.000000
# 75%        210.000000
# max        799.000000
# Name: days_exposition, dtype: float64
#                           count          median            mean  \
#                 days_exposition days_exposition days_exposition
# year_exposition
# 2014                         48           594.0      625.875000
# 2015                        741           455.0      464.669366
# 2016                       2455           210.0      279.386151
# 2017                       7687           102.0      157.470405
# 2018                       7378            64.0       94.150854
# 2019                       1061            23.0       30.775683
#
#                             std
#                 days_exposition
# year_exposition
# 2014                  67.740313
# 2015                 165.137355
# 2016                 208.612279
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Скорость продаж квартир рассчитана корректно, __можно посмотреть на изменение средней  скорости продаж по годам__

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Для определения быстрых и долгих продаж оптимальнее ориентироваться на 25-тый и 75-тый квантили

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Составил сводную таблицу таблицу времени продажи квартир по годам. Мне показалось, что не стоит изображать данные на координатной плоскости, т.к. графики будут пересекаться и визуальная простота исчезнет. Но даже в таблице заметна тенденция к уменьшению усреднённых сроков продажи квартир, и уменьшения разброса. Минимальное значение у 2019 года, но связано это с малой выборкой по времени (несколько месяцев).
#
# Если я правильно понял смысл следующего комментария: в пределах между 25-тый и 75-тый процентилями (или 1ый и 3ий квартили) содежится половина объектов исследования, которая сконцентрирована на кротчайшем временном промежутке, в отличии от других 50%, которые "размазаны". И стоит ориентироваться на первую половину, верно? Методику расчёта я понял.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Только использовать с осторожностью, у нас еще больше 3000 непроданных квартир, которых нет в статистике о средней скорости продаж
#
# У нас три части, первая до 25 процентиля - быстрые продажи, от 25 до 75 нормальные, и все что выше 75-го - долгие

# %%
# check
# Моды на реальных данных

try:
    df_check = pd.read_csv('/datasets/real_estate_data.csv', sep = '\t')
except:
    df_check = pd.read_csv('datasets/real_estate_data.csv', sep = '\t')
    
df_check['days_exposition'].value_counts().to_frame().head(20).plot(kind = 'barh', figsize = (15,6), rot = 0);

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Моды на реальных данных
#
#         Мода (Mo) представляет собой значение изучаемого признака, повторяющееся с наибольшей частотой, т.е. мода – значение признака, встречающееся чаще всего. Медианой (Me) называется значение признака, приходящееся на середину ранжированной (упорядоченной) совокупности, т.е. медиана – центральное значение вариационного ряда.
#
# Выделяются моды на 45 и 60 дней, а значения на 44 и 45 дней, явно имеет техническую причину снятия, из-за формата числа
#
# В нашем проекте — моды могут искажать реальный расчет скорости продажи квартиры

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Если я не ошибаюсь, то где-то это было. Возможно в пробной части курса "Data Science". Чтобы избежать возможного влияния модных значений, стоит их заменить на среднее двух соседних значений. Но в очередной раз убеждаюсь, что совершенствовать проектную работу можно бесконечно.
#
# Разделы проекта разного уровня добавил.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Я хотел обратить внимание на странный формат чисел, не факт что такое встретиться на рабочих проектах, но как строчку для чек-листа проверки данных можно держать в голове
#
# И автоматическое снятие с продажи - искажает параметры скорости продаж, м.б. эта квартира дней 120 продавалась бы, если глубже копать - стоит изучить, что за записи нам попались, однушки, двушки, в каком районе, на каком этаже, есть ли какие-то факторы, которые объединяют все эти записи (например группу на 60 дней)

# %% [markdown]
# # example 1

# %% [markdown]
# #### example 3

# %% [markdown]
# ##### example 4

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# стоит выделять разделы проекта заголовками разного уровня, за уровень отвечает количество знаков #
#
#         # example 1
#
#         #### example 3
#
#         ##### example 4

# %% [markdown]
# ### Задание №2
# Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
#   - общей площади;
#   - жилой площади;
#   - площади кухни;
#   - количество комнат;
#   - типа этажа, на котором расположена квартира (первый, последний, другой);
#   - даты размещения (день недели, месяц, год);

# %%
data.plot(x='total_area', y='last_price', kind='scatter', alpha=0.07, figsize=(15,5), grid=True, 
          title='Соотношение цены и общей площади')
plt.ylabel('Количество публикация, шт.')
plt.xlim(0, 150)
plt.ylim(0, 20000000)
plt.show()

# %%
studio      = data.loc[data['rooms']==0, ['rooms', 'last_price', 'total_area']]
one_room    = data.loc[data['rooms']==1, ['rooms', 'last_price', 'total_area']]
two_rooms   = data.loc[data['rooms']==2, ['rooms', 'last_price', 'total_area']]
three_rooms = data.loc[data['rooms']==3, ['rooms', 'last_price', 'total_area']]
four_rooms  = data.loc[data['rooms']==4, ['rooms', 'last_price', 'total_area']]
five_rooms  = data.loc[data['rooms']==5, ['rooms', 'last_price', 'total_area']]

corr_info = []
flat_type = [studio, one_room, two_rooms, three_rooms, four_rooms, five_rooms]
for tp in flat_type:
     corr_info.append([tp['rooms'].unique()[0], tp['total_area'].corr(tp['last_price'])])
corr_table = pd.DataFrame(data=corr_info, columns=['rooms', 'correlation_coef'])

corr_table.plot(x='rooms', y='correlation_coef', style='o-', figsize=(15,5), grid=True, 
                title='Коэффициент корреляции Пирсона, показывающий зависимость между стоимостью и площадью квартир')
plt.xlim(0, 5)
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# На графике просматривается тёмная область в которой сконцентрировано большинство квартир. Эта масса квартир ограничена двумя линиями: максимумом и минимумом стоимости. Максимум имеет форму прямой, и при использовании апроксимации (округления), можно вывести линейную зависимость. Минимум имеет форму пилы, напренная зубьями вниз. Каждый новый зуб - это появление квартир с бОльшим количеством комнат, но с той же общей площадью. Из-за большого количества квартир одной площади - стоимость проседает.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />  Можно попробовать настроить вид точечных графиков
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)
#
# Примеры расчета коэф. корреляции и не только
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?ysclid=l9ev0utyg728177057)

# %%
data.plot(x='living_area', y='last_price', kind='scatter', alpha=0.1, figsize=(15,5), grid=True,
         title='Соотношение цены и жилой площади')
plt.ylabel('Стоимость квартиры, руб. х 10^7')
plt.xlim(0, 100)
plt.ylim(0, 30000000)
plt.show()

data.plot(x='kitchen_area', y='last_price', kind='scatter', alpha=0.1, figsize=(15,5), grid=True,
         title='Соотношение цены и площади кухни')
plt.ylabel('Стоимость квартиры, руб. х 10^7')
plt.show()

# %% [markdown]
# Среди значений _площади кухни_ и _общей площади_, бОльшая зависимость просматривается не от их величены, а от количества однотипных квартир. На графике особо выделяются вертикальны риски - это огромный разброс цен, среди квартир с одинаковыми площадями.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Импорт библиотек стоит выносить на первые строки проекта, так коллегам будет удобнее настроить свои рабочие места под наши требования

# %%
sns.set(rc={'figure.figsize':(15,8)})
sns.boxplot(x='rooms', y='last_price', data=data)
# Out:
# <AxesSubplot:xlabel='rooms', ylabel='last_price'>

# %% [markdown]
# Если соединить медианы, то получится линия сходая с плавно растущей параболой (а точнее только правая её половина). Тоже самую зависимость можно заметить для минимальной цены квартир, только в этом случа центро параболы (ей мин. значение) располагается над 2х комнатными картирами, и от этой точки симметрично начинает расти.

# %%
sns.boxplot(x='floor_type', y='last_price', data=data)
plt.show()

# %% [markdown]
# Квартиры, расположенные на первом этаже дешевле от рыночной стоимости, в отличии от квартир последнего этажа, которы не так сильно теряют в цене относительно других этажей.

# %%
sns.boxplot(x='day_week_exposition', y='last_price', data=data)
plt.show()
sns.boxplot(x='month_exposition', y='last_price', data=data)
plt.show()
sns.boxplot(x='year_exposition', y='last_price', data=data)
plt.show()

# %% [markdown]
# Зависимость между стоимостью и _днём_ или _месяцем_ публикации - отсутствует либо крайне мала.Что касается зависимости от _года публикации_, то на графике замотно, что средняя и медианная стоимость квартир уменьшалась в 2015 года. Последующие 3 года имеют крайне сходижие значения. Информация за крайние года (2014 и 2019) не полная, по этой причине сделанный по ним вывод, может оказаться неточным или ощибочным.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Не стоит ориентироваться на 2014 год, __т.к. кол-во объявлений было небольшим,__ а стоимость объявлений высокой, может быть это были маркетинговые объявления в начале работы сервиса или сам рынок только формировался ...
#
# Можно посмотреть на изменение по годам средней площади продаваемых квартир и кол-ва объявлений

# %% [markdown]
# **Задание №3:** Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`.

# %%
mean_prise_meter = data[['locality_name', 'price_meter']]

#top10_locality_name = data['locality_name'].value_counts().head(10)
top_10_location = ['Санкт-Петербург', 'Мурино', 'п. Шушары', 'Всеволожск', 'Пушкин',
                   'Колпино', 'п. Парголово', 'Гатчина', 'дер. Кудрово', 'Выборг']
top_10_location_prise_meter = mean_prise_meter[mean_prise_meter['locality_name'].isin(top_10_location)]
top_10_location_prise_meter = top_10_location_prise_meter.groupby('locality_name')\
    ['price_meter'].mean().astype('int').sort_values(ascending=False)

mean_prise_meter = mean_prise_meter.groupby('locality_name')['price_meter'].mean().astype('int')

print('СТОИМОСТЬ КВАДРАТНОГО МЕТРА (значения указаны в рублях)')
display('Топ 10 популярных мест:', top_10_location_prise_meter, '_______________________')
display('Топ 10 дорогих мест:', mean_prise_meter.head(10), '_______________________')
display('Топ 10 дешевых мест:', mean_prise_meter.tail(10))
# Out:
# СТОИМОСТЬ КВАДРАТНОГО МЕТРА (значения указаны в рублях)
# 'Топ 10 популярных мест:'
# locality_name
# Санкт-Петербург    111247
# Пушкин             102812
# дер. Кудрово        92441
# п. Парголово        90235
# Мурино              86027
# п. Шушары           78498
# Колпино             75275
# Гатчина             68891
# Всеволожск          68722
# Выборг              58475
# Name: price_meter, dtype: int32
# '_______________________'
# 'Топ 10 дорогих мест:'
# locality_name
# no_name             93075
# Бокситогорск        17456
# Волосово            39846
# Волхов              35042
# Всеволожск          68722
# Выборг              58475
# Высоцк              27397
# ГП Большая Ижора    51355
# ГП Будогощь         31184
# ГП Виллози          56902
# Name: price_meter, dtype: int32
# '_______________________'
# 'Топ 10 дешевых мест:'
# locality_name
# п. станции Приветнинское    57079
# п. станции Свирь            11481
# с. Копорье                  42008
# ...

# %% [markdown]
# Величина _стоимости кв._ метра недвижимости нагляда видна в таблицах. Единственное, что можно добавить это два основных фактора, которые играют максимальную роль: размер населённого пункта (вернее развитая в нём _инфраструктура_), и _расстояние_ до Санкт-Петербурга. Цены округлены для удобства.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# ТОП-10 рассчитан корректно
#
# не стоит применять переменные с ручным заполнением, при изменении выборки, выводы будут искажены
#
# Недостаточно найти числа, стоит их показать красиво, удобно и наглядно, чтобы одного взгляда хватило, где самые самые, а где подешевле 📊

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Я согласен, что хотя бы в виде отформатированной таблицы, а лучше график, отобранные данные выглядели бы презентабельно. Но эти примитивные таблицы - деинственное, что у меня получилось. Я столкнулся с проблемой: после применения методов .value_counts() или .groupby(), я не могу обратиться к данным которые получаются в результате. Это уже не таблица, не датафрэйм. У меня получается вычленить только численные значения. А название населённых пунктов мне не достать, по крайней мере я пока не знаю как работать с особым типом данных DataFreamGroupby.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />поможет
#
#         .to_frame()

# %%
# check
top_10_location_prise_meter.to_frame()
# Out:
#                  price_meter
# locality_name
# Санкт-Петербург       111247
# Пушкин                102812
# дер. Кудрово           92441
# п. Парголово           90235
# Мурино                 86027
# п. Шушары              78498
# Колпино                75275
# Гатчина                68891
# Всеволожск             68722
# Выборг                 58475

# %% [markdown]
# **Задание №4:** Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города.

# %%
price_per_km = data[['locality_name', 'city_centers_nearest_km', 'last_price', 'rooms']]
price_per_km = price_per_km[price_per_km['locality_name']=='Санкт-Петербург']
price_per_km = price_per_km[price_per_km['city_centers_nearest_km']<=30]

rooms_count = sorted(data['rooms'].unique())
for flat in rooms_count:
    price_per_km.loc[data['rooms']==flat, ['city_centers_nearest_km', 'last_price']]\
        .groupby('city_centers_nearest_km')['last_price'].mean()\
            .plot(style='o-', label=str(flat)+' комн.', legend=True, figsize=(15,7), grid=True)
plt.title('График зависимости ср. стоимости квартиры от расстояния до центра города')
plt.ylabel('Стоимость квартиры, руб. х 10^7')
plt.show()

rooms_count = sorted(data['rooms'].unique())
for flat in rooms_count:
    price_per_km.loc[data['rooms']==flat, ['city_centers_nearest_km', 'last_price']]\
        .groupby('city_centers_nearest_km')['last_price'].count()\
            .plot(style='o-', label=str(flat)+' комн.', legend=True, figsize=(15,7), grid=True)
plt.title('График зависимости количества квартиры от расстояния до центра города')
plt.ylabel('Кол-во квартиры, шт.')
plt.show()

# %% [markdown]
# График можно выделить несколько смысловых отрезков:
# - 0-3км. "Исторический центр" - это единственное, что определяет дороговизнунедвижимости. Ввиду плотной застройки, огромного количества общественных мест, и т.п. - могут отсутствовать некоторые удобства: свободная парковка, детские сады, школы.
# - 3-7км. "Деловой центр" - районы, которые свободны от туристов, и не так сильно обременены историческим наследством, чтобы иметь свободную возможность к развитию современной городской инфраструктуре. Здесь одно из небольших мест контрации больших квартир с кол-вом комнат от 4 и более.
# - 7-18км "Старые и новые жилые районы" - плавное снижения стоимости квартиры. Некоторые районы могут иметь небольшие отличия между собой в типе жилого фонта, транспортной доступности, что влияет на ср. стоимость. Особая большая концентрация "однушек", "двушек" и "трёшек" на 12ом и 15ом километрах от центра.
#
# Если можно было бы вместе с исходными данными получить пояснение, какая точка принята за "центр города", то можно было бы с хорошей точностью вычислить и локализовать жилые эти районы.
#
# Ещё следует добавить, что 4х и 5ти комнатные квартиры, а так же студии - немногочисленные категории, так что на их стоимость сильно влияет расположение. Квартиры с 1ой, 2мя и 3мя комнатами - очень популярны, их можно найти практически в любом районе, введу этого их стоимость находится в равномерной зависимости от центра (единственное, что на разных участках - разный коэфициент этой зависимости).

# %%
display(data[(data['city_centers_nearest_km']==27) & (data['rooms']==2) & (data['locality_name']=='Санкт-Петербург')])
# Out:
#        locality_name  rooms  last_price  price_meter  total_area  living_area  \
# 748  Санкт-Петербург      2    14350000       193918        74.0         30.0
#
#      kitchen_area  balcony  ceiling_height  floors_total  ...  \
# 748          25.0        0            3.13             5  ...
#
#      city_centers_nearest_km parks_around3000  parks_nearest  \
# 748                     27.0                1         1496.0
#
#      ponds_around3000  ponds_nearest  days_exposition  first_day_exposition  \
# 748                 0            0.0            128.0            2017-11-28
#
#      day_week_exposition  month_exposition  year_exposition
# 748                    1                11             2017
#
# [1 rows x 28 columns]

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Молодец, у тебя получилось сгруппировать и построить график изменения средней цены в зависимости от расстояния от центра

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит изучить записи, которые привели к выбросу на 27-м км.
#
# Стоит посмотреть на категории квартир, которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Причиной выброса на 27-м км. - единственная и видимо неповторимая двушка за ~ 15млн.руб.
#
# Легенда графиков записывается в порядке изображения графиков. Я хотел соблюсти порядко расположения графиков и их лэйблов в легенде. Для этого нужно было их отсортировать в обратом порядке. Но по какой то причине у меня не работает строчка
#
#         data['rooms'].unique().sort(reverse=True)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Можешь показать весь код, который у тебя не получился

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Категорий квартир с более дешевой стоимостью намного больше на 3-м километре, чем на пятом, возможно отсюда падение и пик...
#
# возможно к этому фактору добавляются и другие

# %%
# способы группировки и сортировки информации

(
    data
     .query('locality_name == "Санкт-Петербург"')
     .query('3 <= city_centers_nearest_km <=5 ')
     .groupby(['city_centers_nearest_km', 'floor_type'])['last_price']
     .agg(['count', 'mean'])
     .style.format("{:,.0f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_739eb_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>    </tr>    <tr>        <th class="index_name level0" >city_centers_nearest_km</th>        <th class="index_name level1" >floor_type</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_739eb_level0_row0" class="row_heading level0 row0" rowspan="3">3.0</th>
#                         <th id="T_739eb_level1_row0" class="row_heading level1 row0" >другой</th>
#                         <td id="T_739eb_row0_col0" class="data row0 col0" >184</td>
#                         <td id="T_739eb_row0_col1" class="data row0 col1" >10,113,991</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# <a id='section_5'></a>
# # 5. Общий вывод

# %% [markdown]
# Среди всего числа квартир можно выделить в особые группы типовые квартиры (например: старого фонда, новые жилые кварталы). Они имеют большую численность, ряд одинаковых параметров, благодаря чему для них можно построить точную математическую модель ценообразования, которую можно встроить в сайт. Для собственика это даст возможность оценить свою квартиру, а для покупателя понять, является ли цена конкретной квартиры рыночной, или же она завышена/занижена по какой-то причине. Критерии для выборки групп однотипных квартир выведены в исследовании выше.
#
# Основные зависимость влияющия на стоимость это количество схожих по характеристикам квартир. Из важных характеристик стоит выделить количество комнат, площади(общая, жилая и кухни), месяц публикации объявления, общее количество этажей в доме, расстояние до центра города в метрах.
#
# Ко второй очереди я бы отнёс: высота потолков; этаж квартиры, в частности тип («первый», «последний», «другой»), балкон,
# количество и расстояние до ближайшего аэропорта, парка и водоёма.
#
# На основе проделанной работы, можно сформулировать ряд недочётов в исходных данных, и передать их в качестве обратной связи. При последующем обращении это увеличит выборку данных, и сэкономит ресурсы на предобработке. Помимо перечня недочётов, можно передать ряд требований к данным, что так же повысит точность исследования.
#
# Следует уточнить, что алгоритм ценообразования определён для популярных квартир (не больше 5-ти комнат). Большие кварти - достаточно малочисленные и для них есть возможность выполнить оценку вручную. Если требуется точная стоимость.
#
# В перечень параметров в объявлении стоит добавить год постройки дома. Если он уже есть, то при следующем исследовании стоит выгрузить и эти данные. Это позволит сруппировывать квартиры по возросту и точнее обрабывать пропуски.

# %% [markdown]
# <div class="alert alert-dan
#             ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Вывод хороший, сформирована рекомендация бизнесу, молодец
#
# Можно добавить значения исследуемых параметров (средние или медианные)

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнил исследовательскую работу, молодец, показал хороший уровень навыков программирования
#
# Критические ❌ комментарии
#
#
# + настроить загрузку сетевой версии
# + проверить корректность заполнения пропусков синтетическими данными
# + сменить тип данных
# + настроить фильтрацию редких значений в п. 2.4
# + подправить гистограммы в п.4.1
# + дополнить итоговый вывод цифрами и сравнениями
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# <p> Доп. материал: методы группировки и расчета суммы, средних и т.д.
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
#  Интересная функция в библиотеке пандаса
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)
#
# [Как выбрать определенные столбцы из DataFrame](https://dfedorov.spb.ru/pandas/03.%20%D0%9A%D0%B0%D0%BA%20%D0%B2%D1%8B%D0%B1%D1%80%D0%B0%D1%82%D1%8C%20%D0%BF%D0%BE%D0%B4%D0%BC%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2%D0%BE%20%D0%B8%D0%B7%20DataFrame_.html?ysclid=l9sps5lt6g576766938)

# %% [markdown]
# ## Бонус

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />Диаграмма рассеяния

# %%
# check
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# check
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'city_centers_nearest']])
plt.gcf().set_size_inches(12,12);

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена трешки')


data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='living_area', alpha=0.5, figsize=(15,8), c = 'r', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Заполнение пропусков синтетическими данными во всей красе, стоит или изменить алгоритм, или оставить пропуски

# %%
# check
price_pivot_area = data.pivot_table(index='last_price', values=([
    'total_area', 'living_area', 'kitchen_area']), aggfunc='median')
price_pivot_area = price_pivot_area.reset_index()
# Посмотрим на диаграммы рассеяния для столбцов 'total_area', 'living_area', 'kitchen_area'.
for row in ['total_area', 'living_area', 'kitchen_area']:
    sns.relplot(data=price_pivot_area, x='last_price', y=row, kind='scatter')

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод

# %% [markdown]
# **P.S.:** Если бы этот проект я демонстрировал клиенту, то я оформил его по другому. Но так как это учебный проект, но я оставляю некоторые строчки кода, чтобы продемонстрировать каким образом производилась работа с данными. Практически в каждой колонке даннных, присутствуют выбросы, которые я старался отсечь. Допускаю, что я поскромничал и оставил лишние данные. В первую очередь я отправляю проект дабы получить комментарии, т.к. на разных этапая я видел несколько путей решения и не знал какой выбрать. Мне очень интересно узнать взгляд со стороны.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />спасибо за комментарий

# %%
display(data.groupby('rooms')['living_area'].median())
# Out:
# rooms
# 0    18.0
# 1    17.7
# 2    30.5
# 3    45.0
# 4    63.0
# 5    88.0
# Name: living_area, dtype: float64
